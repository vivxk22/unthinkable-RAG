# %% [markdown]
# ### DATA INGESTION

# %%
###Document Structure

from langchain_core.documents import Document
# Out:
# /home/sudoverse/project/rag/.venv/lib64/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
#from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %%
## Create a simple txt file
import os
os.makedirs("../data/pdf",exist_ok=True)

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-11T18:11:55+00:00', 'source': '../data/pdf/sujit.pdf', 'file_path': '../data/pdf/sujit.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-03-11T18:11:55+00:00', 'trapped': '', 'modDate': 'D:20260311181155Z', 'creationDate': 'D:20260311181155Z', 'page': 0}, page_content='SUJIT DAS\nEmail: das078141@gmail.com\nMobile:\n+91-8822199101\nLinkedIn: Sujit Das\nEducation\n• National Institute of Technology, Silchar\nAssam, India\nBachelor of Technology - Electrical Engineering\nOctober 2023 - May 2027\n• Jawahar Navodaya Vidyalaya Pailapool, Cachar\nAssam, India\nSenior Secondary - CBSE; Percentage: 73%\nMay 2020 - March 2022\n• Jawahar Navodaya Vidyalaya Pailapool, Cachar\nAssam, India\nSecondary - CBSE; Percentage: 75%\nJanuary 2018 - March 2020\nSkills\n• Core Subjects: Electrical Machines, Control Systems, Power Systems, Switchgear & Protection\n• Simulation Tools: MATLAB/Simulink, MiPower, PSpice\n• Electronics: Analog & Digital Circuit Design, Embedded Systems, Microcontroller Programming\n• Tools: MS Office, Canva\n• Soft Skills: Leadership, Event Management, Writing, Public Speaking\nPosition of Responsibility\n• Electra Society\nNIT Silchar\nExecutive Team Member (Full-time)\nAugust 2024 - July 2025\n◦Organized Core Workshops: Successfully organized and conducted multiple workshops on key electrical\nengineering topics such as CIRCUIT DESIGN, CONTROL SYSTEMS, and EMBEDDED SYSTEMS,\nwhich enhanced both my technical skills and project management abilities.\n◦Worked closely with professors to arrange seminars, bridging the gap between academic knowledge and practical\napplication.\nInternship Experience\n• Oil and Natural Gas Corporation Limited (ONGC), Srikona, Assam\nOnsite\nIndustrial Trainee [Certificate]\nMay 2025 – July 2025\n◦Industrial Training:\nGained practical exposure to electrical infrastructure used in oil and gas production facilities,\nincluding power distribution systems and high-voltage equipment.\n◦Power System Operations:\nObserved real-time power transmission, grid protection mechanisms, and switchgear\noperations used to ensure safe and reliable energy supply.\n◦Technical Drafting:\nUtilized AutoCAD for interpreting and assisting in the preparation of electrical layouts,\nsingle-line diagrams, and equipment placement drawings.\n◦Plant Safety and Maintenance:\nStudied industrial safety protocols, preventive maintenance practices, and\noperational procedures followed in large-scale energy production environments.\nProjects\nNational Institute of Technology, Silchar\nOnsite\nSolar Photovoltaic System Modeling and Performance Analysis (Ongoing)\n(MATLAB/Simulink, Solar Energy Systems, Power Electronics)\n• Objective: Designing and analyzing a grid-connected solar photovoltaic (PV) system to improve renewable energy\nintegration in power systems.\n• System Modeling: Developing a detailed PV array and inverter model using MATLAB/Simulink to study power\ngeneration under varying environmental conditions.\n• Performance Analysis: Evaluating system performance based on solar irradiance, temperature variations, and\npower output characteristics.\n• Expected Outcome: Improved efficiency of solar PV systems and better understanding of renewable energy\nintegration into modern power grids.\nAchievements\n• Successfully organized and managed technical and cultural events at NIT Silchar.\n• Volunteered for the NCST/JDST Dakshana Selection Test 2026 organized by Dakshana India Educational\nTrust at JNV West Jaintia Hills, Meghalaya, assisting in the selection process for Dakshana scholarship\nbeneficiaries [Certificate].\n• Won 1st Prize in Debate Competition, demonstrating strong communication and public speaking skills.\nOther Interests/Extracurricular Activities\n• Actively involved in cricket, fostering teamwork, discipline, and strategic think ...
